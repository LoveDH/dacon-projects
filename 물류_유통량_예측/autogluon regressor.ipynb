# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

train = pd.read_csv('data/train_updated.csv')
test = pd.read_csv('data/test_updated.csv')
submission = pd.read_csv('data/sample_submission.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10300/567032963.py in <module>
#       1 import pandas as pd
# ----> 2 from autogluon.tabular import TabularPredictor
#       3
#       4 train = pd.read_csv('data/train_updated.csv')
#       5 test = pd.read_csv('data/test_updated.csv')
#
# c:\Users\KDH\venv\autogluon\lib\site-packages\autogluon\tabular\__init__.py in <module>
#       2
#       3 from autogluon.common.features.feature_metadata import FeatureMetadata
# ----> 4 from autogluon.core.dataset import TabularDataset
#       5
#       6 try:
#
# c:\Users\KDH\venv\autogluon\lib\site-packages\autogluon\core\__init__.py in <module>
# ----> 1 from .dataset import TabularDataset
#       2 from .space import *
#       3 from .task.task import *
#       4 from .task.task import Task
#       5 from .decorator import *
#
# ...

# %%
label = 'INVC_CONT'
print("Summary of class variable: \n", train[label].describe())

# %%
save_path = 'agregressor'
predictor = TabularPredictor(label=label, path=save_path, problem_type='regression').fit(train)#, presets='best_quality')

# %%
predictor.fit_summary()
